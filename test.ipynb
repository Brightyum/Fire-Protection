# %%
class Load:
    def __init__(self):
        self.txt_file_path_list = [
            # "TXT\재난현장표준작전절차.txt", # 원본
            "TXT\재난현장표준작전절차_지휘통제절차.txt", # 지휘통제절차 SOP 100번대
            # "TXT\재난현장표준작전절차_화재유형별 표준작전절차.txt", # 화재유형 SOP 200번대
            # "TXT\재난현장표준작전절차_사고유형별 표준작전절차.txt", # 사고유형 SOP 300번대
            # "TXT\재난현장표준작전절차_구급 단계별 표준작전절차.txt", # 구급유형 SOP 400번대
            # "TXT\재난현장표준작전절차_상황 단계별 표준작전절차.txt", # 상황유형 SOP  500번대
            "TXT\재난현장표준작전절차_현장 안전관리 표준지침.txt" # 현장 안전관리 표준지침 SSG 1~8
        ]
        self.txt_list = []
    
    def get_file_path(self):
        pass

    def get_txt_list(self):
        for file_path in self.txt_file_path_list:
            
            # 파일 읽기
            with open(file_path, "r", encoding="utf-8") as file:
                lines = file.readlines()

                self.txt_list.append(lines)
        
        return self.txt_list

if __name__ == "__main__":
    test = Load()

    result = test.get_txt_list()

    print(result)
# Out:
# [[['재난현장 표준작전절차\n', 'SOP 101 지휘권 확립\n', '1 지휘권 확립 원칙\n', '1.1 모든 재난 현장의 지휘체계는 단일 현장지휘체계이며 지휘권 이양 절차에 따라 지휘권을  \n', '이양받은 지휘관이 현장지휘관이 된다.\n', '1.2 선착대장은 현장에 도착과 동시에 반드시 지휘권을 무전으로 선언한다 . 다만, 상시 운영되는  \n', '소방서 긴급구조지휘대의 지휘대장 (지휘팀장 , 대응단장 등)이 현장에 함께 도착한 경우 \n', '지휘대장이 지휘권을 선언한다 .\n', '1.2.1 후착한 지휘대장은 선착대장이 지휘권을 선언하지 않은 경우 즉시 지휘권을 선언하여 \n', '재난현장 지휘권을 확립한다 .\n', '     ① 현장대원 안전관리를 점검한다 .\n', '     ② 자원을 배치한다 .\n', '     ③ 위험지역 내에서 활동 중인 모든 대원의 위치를 파악한다 .\n', '     ④ 전술상황의 기록을 유지한다 .\n', '     ⑤ 임무 수행 중인 출동대로부터의 진행 상황에 대한 보고를 요청한다 .\n', '2 선착대장 지휘권 확립 절차\n', '2.1 지휘권 행사는 선착대장이 무전을 통해 119종합상황실 (이하 상황실 )과 후착대에 최초상황을  \n', '전파함으로써 이루어지며 최초상황 보고 내용은 다음 사항을 포함한다 . \n', '    ① 현장에 도착한 출동대 명칭을 전파한다 . \n', '    ② 연소 상황, 구조대상자 (사상자 ) 발생 등 관찰되는 재난 정보를 전파한다 . \n', '    ③ 건물용도 , 규모, 건축 방식을 파악 전파한다 .\n', '    ④ 위험 요소, 대원 안전과 직결되는 사항을 파악 전파한다 .\n', '    ⑤ 지휘관 신분, 지휘 위치 등을 포함한 지휘권을 선언한다 . \n', '    ⑥ 시도 중이거나 시도 예정인 소방 활동 상황을 전파한다 .\n', '    ⑦ 공격․방어․병행전략 등 전략을 선언한다 . \n', '    ⑧ 필요한 자원 등 지원의 범위를 결정하고 요청 및 전파한다 . \n', '3 현장지휘관 지휘전술\n', '3.1 현장지휘관이 선택할 수 있는 지휘전술은 이동지휘 , 전진지휘와 고정지휘로 나뉘며 현장 \n', '상황에 맞는 적절한 전술을 선택한다 .\n', '3.1.1 이동지휘는 현장지휘관이 특정장소 (현장지휘소 )에 머물러 있지 않고 재난현장을 돌아\n', '다니며 지휘하는 형태를 말한다 .\n', '3.1.2 전진지휘는 현장지휘관이 위험지역으로 진입하여 대원들과 임무수행을 함께 하는 형태를  \n', '말하며 아래와 같은 상황에서 실시한다 .\n', '     • 대원 안전에 대한 현장지휘관의 근접 감독･지원이 필요한 상황\n', '     • 현장지휘관의 지원이 있어야만 즉각적 인명구조가 가능한 상황\n', '     • 현장지휘관의 지원이 있으면 초기 화재진압이 가능한 상황\n', '3.1.3 고정지휘는 현장지휘관이 화재 건물(지역)의 현장지휘소에 머물며 지휘하는 형태를 \n', '말한다 .\n', '3.2 현장지휘관 재난 규모가 크고 복잡하거나 빠른 확대 가능성이 있는 재난의 경우에는 초기\n', '부터 고정지휘를 한다.\n', '3.3 지휘권을 이양받은 현장지휘관은 고정지휘를 하고, 단위지휘관은 임무에 따라 이동지휘 , 전진\n', '지휘, 고정지휘 중 한 가지를 선택할 수 있다.2.2 선착대장은 상황에 따라 재난 현장의 전체를 돌아보며 다음 사항을 확인하고 필요시 즉각 \n', '전파한다 .\n', '    ① 최초 상황평가를 검토･보완한다 .\n', '    ② 관계인 또는 목격자가 제공하는 믿을 만한 정보를 취득한다 .\n', '    ③ 화재/연기의 위치와 상태 변화를 확인한다 .\n', '    ④ 구조대상자 , 위험 요소 유무를 파악한다 .\n', '    ⑤ 최초 상황평가 시 결정한 전략과 지휘 위치의 적절성을 검토한다 .\n', '    ⑥ 임무부여 , 자원배치 , 대응활동계획 등의 적절성을 검토한다 .\n', '재난현장 표준작전절차\n', 'SOP 102 상황평가 및 적용\n', '1 상황평가\n', '1.1 재난현장에서 목표 우선순위 설정, 대응활동계획 수립 조정 및 검토를 위해 현장지휘관은  \n', '지속적인 상황평가를 실시해야 한다.\n', '1.2 현장지휘관은 상황평가를 할 때 가장 심각한 영향을 초래할 수 있는 요소를 찾아내고 \n', '피해 완화에 집중하기 위해 아래 사항을 반영한다 .\n', '1.2.1 전체 상황을 빠르게 훑어본다 .\n', '1.2.2 우선순위에 따라 현장 주요요소를 정리한다 .\n', '1.2.3 주요요소와 관련된 추가정보를 찾는다 .\n', '1.2.4 재난에 영향을 미치는 중요한 요소에 집중한다 . \n', '1.2.5 육안 관찰한 것과 상황보고를 받은 것을 신속하고 적절하게 반영한다 .\n', '1.3 상황평가는  선착대장이 실시하는 초기 상황평가와 선착대장 이후에 지휘권을 이양받는 \n', '현장지휘관이 실시하는 상세 상황평가로 구분한다 .\n', '2 선착대장 상황평가 절차\n', '2.1 선착대장은 아래 단계별로 초기상황 평가 및 판단에 필요한 정보를 수집한다 . \n', '2.1.1 출동지령 내용으로 재난유형 , 규모, 인명피해 등의 정보를 수집한다 .\n', '2.1.2 출동 중 신고내용 및 날씨, 시간대 , 대상물 등 상황실 추가정보를 파악한다 .\n', '2.1.3 현장도착 즉시 재난 건물(지역)과 주변 건물(지역)의 배치, 재난 진행상황을 파악한다 .\n', '2.1.4 현장 도착 후 관계자 진술, 구조대상자 및 인명대피 유무, 연소확대 상황, 현장안전 \n', '등의 정보를 수집한다 .\n', '2.2 선착대장은 현장에 도착하면 육안관찰을 통하여 다음 정보를 수집한다 .\n', '2.2.1 눈에 보이는 구조대상자의 상황을 파악한다 .\n', '2.2.2 화재층 및 상층 등으로의 연소확대 상황 및 화재로 인한 인접건물에 대한 영향 등을 \n', '파악한다 .\n', '2.2.3 건물붕괴 우려 등 대원안전과 관련된 정보를 확인한다 .\n', '2.2.4 인명대피를 할 수 있는 피난시설 (비상구 및 피난계단 ) 등의 유무를 확인한다 .\n', '3 후착 현장지휘관 상황평가 절차\n', '4 안전관리 상황평가2.2.5 기타 대응활동에 참고할 수 있는 정보를 파악한다 .\n', '2.3 선착대장은 초기상황평가 및 현장에 도착하여 육안 관찰을 통해 파악한 정보에 기초하여  대응\n', '할 전략 등을 선택하고 추가 정보에 따라 수정･보완한다 . \n', '3.1 선착대장이 지휘권을 장악하고 있는 현장에 도착한 지휘대장은 다음과 같이 상황평가를  실시한다 .\n', '3.1.1 선착대장이 수집한 초기 상황정보 ･현장도착 육안관찰 정보 등을 선착대장의 진행상황 \n', '보고(브리핑 )를 토대로 절차에 따라 지휘권을 이양받는다 .\n', '3.1.2 지휘권을 이양받은 현장지휘관은 상황평가를 재실시하고 전략 및 대응활동 계획에  반영\n', '한다.\n', '3.1.3 재난이 종결될 때까지 지속적으로 상황평가를 실시하고 그 결과를 전략 및 대응활동\n', '계획에 반영한다 . \n', '3.1.4 지휘대장은 지휘대원에게 , 통제단장은 대응계획부에 상세한 상황평가를 실시하도록 \n', '지시할 수 있다. \n', '4.1 현장지휘관은 대원안전과 관련된 다음의 화재현장 주요요소를 예의주시하고 적절한 조치를 \n', '강구하며 현장지휘관 중심의 ‘진입 금지 명령권 ’을 확행할 수 있다.\n', '    ① 숨겨진 공간 내에 화재가 있는 경우\n', '    ② 진행 중인 화재의 상층부에서 임무를 수행하는 경우\n', '    ③ 시계(視界)가 0(zero) 인 경우\n', '    ④ 통상적인 소요 시간이 지났는데도 화점을 발견할 수 없는 경우\n', '    ⑤ 화재진압 중인 출동대가 지원을 요청하는 경우\n', '    ⑥ 건물 내의 출동대가 ‘초진’을 보고함에도 불구하고 현장지휘소에서 여전히 진행 중인 \n', '화재를 목격하는 경우\n', '    ⑦ 바람을 타고 빠르게 번지는 화재인 경우(예: 산불)\n', '    ⑧ 특수한 현상의 징후가 보이는 화 ...
